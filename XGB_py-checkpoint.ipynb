# %% [markdown]
#  # Importing All Required Libraries

# %%
import numpy as ns
import pandas as pg
import matplotlib.pyplot as pla
import seaborn as snd

# %% [markdown]
#  # Loading the Dataset

# %%
df = pg.read_csv("D:\Dataset\Wholesale customers data.csv")
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %% [markdown]
#  # Data Cleaning using Pandas

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head(12)
# Out:
#     Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0         2       3  12669   9656     7561     214              2674
# 1         2       3   7057   9810     9568    1762              3293
# 2         2       3   6353   8808     7684    2405              3516
# 3         1       3  13265   1196     4221    6404               507
# 4         2       3  22615   5410     7198    3915              1777
# 5         2       3   9413   8259     5126     666              1795
# 6         2       3  12126   3199     6975     480              3140
# 7         2       3   7579   4956     9426    1669              3321
# 8         1       3   5963   3648     6192     425              1716
# 9         2       3   6006  11093    18881    1159              7425
# 10        2       3   3366   5403    12974    4400              5977
# 11        2       3  13146   1124     4523    1420               549
#
#     Delicassen
# 0         1338
# 1         1776
# 2         7844
# ...

# %%
df.tail(21)
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 419        1       3   8861   3783     2223     633              1580
# 420        1       3   4456   5266    13227      25              6818
# 421        2       3  17063   4847     9053    1031              3415
# 422        1       3  26400   1377     4172     830               948
# 423        2       3  17565   3686     4657    1059              1803
# 424        2       3  16980   2884    12232     874              3213
# 425        1       3  11243   2408     2593   15348               108
# 426        1       3  13134   9347    14316    3141              5079
# 427        1       3  31012  16687     5429   15082               439
# 428        1       3   3047   5970     4910    2198               850
# 429        1       3   8607   1750     3580      47                84
# 430        1       3   3097   4230    16483     575               241
# ...

# %%
df[df.index==100]
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 100        2       3  11594  7779    12144    3252              8035
#
#      Delicassen
# 100        3029

# %%
df[df.index.isin(range(3,39))]
# Out:
#     Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 3         1       3  13265   1196     4221    6404               507
# 4         2       3  22615   5410     7198    3915              1777
# 5         2       3   9413   8259     5126     666              1795
# 6         2       3  12126   3199     6975     480              3140
# 7         2       3   7579   4956     9426    1669              3321
# 8         1       3   5963   3648     6192     425              1716
# 9         2       3   6006  11093    18881    1159              7425
# 10        2       3   3366   5403    12974    4400              5977
# 11        2       3  13146   1124     4523    1420               549
# 12        2       3  31714  12319    11757     287              3881
# 13        2       3  21217   6208    14982    3095              6707
# 14        2       3  24653   9465    12091     294              5058
# 15        1       3  10253   1114     3821     397               964
# ...

# %%
df.loc[89]
# Out:
# Channel                 1
# Region                  3
# Fresh               24904
# Milk                 3836
# Grocery              5330
# Frozen               3443
# Detergents_Paper      454
# Delicassen           3178
# Name: 89, dtype: int64

# %%
df.iloc[2:21]
# Out:
#     Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 2         2       3   6353   8808     7684    2405              3516
# 3         1       3  13265   1196     4221    6404               507
# 4         2       3  22615   5410     7198    3915              1777
# 5         2       3   9413   8259     5126     666              1795
# 6         2       3  12126   3199     6975     480              3140
# 7         2       3   7579   4956     9426    1669              3321
# 8         1       3   5963   3648     6192     425              1716
# 9         2       3   6006  11093    18881    1159              7425
# 10        2       3   3366   5403    12974    4400              5977
# 11        2       3  13146   1124     4523    1420               549
# 12        2       3  31714  12319    11757     287              3881
# 13        2       3  21217   6208    14982    3095              6707
# 14        2       3  24653   9465    12091     294              5058
# ...

# %%
df.size
# Out:
# 3520

# %%
df.count()
# Out:
# Channel             440
# Region              440
# Fresh               440
# Milk                440
# Grocery             440
# Frozen              440
# Detergents_Paper    440
# Delicassen          440
# dtype: int64

# %%
df["Grocery"].value_counts()
# Out:
# Grocery
# 1664    2
# 2062    2
# 683     2
# 3600    2
# 6536    2
#        ..
# 7305    1
# 3343    1
# 5034    1
# 8282    1
# 2510    1
# Name: count, Length: 430, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
df.shape
# Out:
# (440, 8)

# %%
df.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Channel               2
# Region                3
# Fresh               433
# Milk                421
# Grocery             430
# Frozen              426
# Detergents_Paper    417
# Delicassen          403
# dtype: int64

# %% [markdown]
#  # Data Visualization using Matplotlib & Seaborn

# %%
snd.pairplot(df)
# Out:
# C:\Users\SAI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
snd.histplot(df["Frozen"])
# Out:
# <Axes: xlabel='Frozen', ylabel='Count'>

# %%
snd.scatterplot(df["Grocery"])
# Out:
# <Axes: ylabel='Grocery'>

# %%
import numpy as nd
import matplotlib.pyplot as pla
X = nd.random.randn(10000)
Y = nd.random.randn(10000)
pla.hist2d(X,Y,bins=30,cmap='Purples_r')
pla.colorbar()
pla.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = pla.figure()
ax = fig.add_subplot(111,projection = '3d')
X1 = nd.random.standard_normal(100)
Y1 = nd.random.standard_normal(100)
Z1 = nd.random.standard_normal(100)
ax.scatter(X1,Y1,Z1)
pla.show()

# %% [markdown]
#  # Split the X&Y

# %%
X1 = df.drop("Channel",axis=1)
Y1 = df["Channel"]

# %%
Y1[Y1 == 2] = 0
Y1[Y1 == 1] = 1

# %% [markdown]
#  # Train_Test_Split

# %%
from sklearn.model_selection import train_test_split
X1_train,X1_test,Y1_train,Y1_test = train_test_split(X1,Y1,test_size=0.1,random_state = 21)
X1_train
# Out:
#      Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 16        3   1020   8816    12121     134              4508        1080
# 66        3      9   1534     7417     175              3468          27
# 152       3  18840   1371     3135    3001               352         184
# 251       1   6134  23133    33586    6746             18594        5121
# 239       1  47493   2567     3779    5243               828        2253
# ..      ...    ...    ...      ...     ...               ...         ...
# 368       3  22335   1196     2406    2046               101         558
# 48        3  11519   6152    10868     584              5121        1476
# 260       1   9193   4885     2157     327               780         548
# 312       2   2137   3737    19172    1274             17120         142
# 207       1   2541   4737     6089    2946              5316         120
#
# [396 rows x 7 columns]

# %%
X1_test
# Out:
#      Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 341       3   2320   5763    11238     767              5162        2158
# 40        3  24025   4332     4757    9510              1145        5864
# 135       3   6300   1289     2591    1170               199         326
# 99        3   9658   2182     1909    5639               215         323
# 256       1  11092   5008     5249     453               392         373
# 219       1   4155    367     1390    2306                86         130
# 179       3   3157   4888     2500    4477               273        2165
# 176       3  45640   6958     6536    7368              1532         230
# 182       3    694   8533    10518     443              6907         156
# 43        3    630  11095    23998     787              9529          72
# 37        3  15168  10556    12477    1920              6506         714
# 277       3   9061    829      683   16919               621         139
# ...

# %%
Y1_train
# Out:
# 16     0
# 66     1
# 152    1
# 251    0
# 239    1
#       ..
# 368    1
# 48     0
# 260    1
# 312    0
# 207    0
# Name: Channel, Length: 396, dtype: int64

# %%
Y1_test
# Out:
# 341    0
# 40     1
# 135    1
# 99     1
# 256    1
# 219    1
# 179    1
# 176    1
# 182    1
# 43     0
# 37     0
# 277    1
# 9      0
# 104    1
# 391    1
# 196    1
# 13     0
# 275    1
# 164    0
# 70     1
# 249    1
# 52     0
# 142    1
# 57     0
# 232    1
# 4      0
# 321    1
# 140    1
# 96     0
# 265    1
# 298    0
# 331    0
# 426    1
# 234    1
# 91     1
# 215    1
# 363    1
# 423    0
# 361    1
# 61     0
# 343    0
# 51     1
# 351    0
# 163    0
# Name: Channel, dtype: int64

# %% [markdown]
# # Installing the XGBoost

# %%
# !pip install xgboost

# %% [markdown]
# # Importing XGBoost

# %%
import xgboost as xgb
df_dmatrix = xgb.DMatrix(data=df,label=Y1)

# %% [markdown]
#  # Importing XGBoost Classifier

# %%
from xgboost import XGBClassifier
params = {
            'objective' : 'binary:logistic',
            'max_depth' : 4,
            'alpha'     : 10,
            'learning_rate' : 1.0,
            'n_estimators'  : 100,
}
xgb_clfn1 = XGBClassifier(**params)
xgb_clfn1.fit(X1_train,Y1_train)
# Out:
# XGBClassifier(alpha=10, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1.0, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# # Prediction from our Model

# %%
Y1_pred = xgb_clfn1.predict(X1_test)

# %%
snd.jointplot(Y1_test)

# %% [markdown]
#  # Checking Accuracy

# %%
from sklearn.metrics import accuracy_score
print("XGBoost model accuracy score: {0:0.4f}".format(accuracy_score(Y1_test,Y1_pred)))
# Out:
# XGBoost model accuracy score: 0.8636
