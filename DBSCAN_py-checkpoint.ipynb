# %% [markdown]
#  # Importing Required Libraries

# %%
import numpy as NR
import pandas as PT
import matplotlib.pyplot as PLE
import seaborn as SYK

# %% [markdown]
#  # Loading the Dataset

# %%
df = PT.read_csv("D:\Dataset\Apple Dataset.csv")
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099058
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093890
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086999
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089152
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091737
# ...           ...         ...         ...         ...         ...         ...
# 10949  2024-05-20  189.330002  191.919998  189.009995  191.039993  191.039993
# 10950  2024-05-21  191.089996  192.729996  190.919998  192.350006  192.350006
# 10951  2024-05-22  192.270004  192.820007  190.270004  190.899994  190.899994
# 10952  2024-05-23  190.979996  191.000000  186.630005  186.880005  186.880005
# 10953  2024-05-24  188.820007  190.580002  188.039993  189.979996  189.979996
#
#           Volume
# ...

# %% [markdown]
#  # Data Cleaning using Pandas

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.head(19)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume
# 0   1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099058  469033600
# 1   1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093890  175884800
# 2   1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086999  105728000
# 3   1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089152   86441600
# 4   1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091737   73449600
# 5   1980-12-19  0.126116  0.126674  0.126116  0.126116   0.097335   48630400
# 6   1980-12-22  0.132254  0.132813  0.132254  0.132254   0.102072   37363200
# 7   1980-12-23  0.137835  0.138393  0.137835  0.137835   0.106380   46950400
# 8   1980-12-24  0.145089  0.145647  0.145089  0.145089   0.111978   48003200
# 9   1980-12-26  0.158482  0.159040  0.158482  0.158482   0.122315   55574400
# 10  1980-12-29  0.160714  0.161272  0.160714  0.160714   0.124037   93161600
# ...

# %%
df.tail(21)
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 10933  2024-04-26  169.880005  171.339996  169.179993  169.300003  169.070679
# 10934  2024-04-29  173.369995  176.029999  173.100006  173.500000  173.264984
# 10935  2024-04-30  173.330002  174.990005  170.000000  170.330002  170.099289
# 10936  2024-05-01  169.580002  172.710007  169.110001  169.300003  169.070679
# 10937  2024-05-02  172.509995  173.419998  170.889999  173.029999  172.795624
# 10938  2024-05-03  186.649994  187.000000  182.660004  183.380005  183.131607
# 10939  2024-05-06  182.350006  184.199997  180.419998  181.710007  181.463882
# 10940  2024-05-07  183.449997  184.899994  181.320007  182.399994  182.152924
# 10941  2024-05-08  182.850006  183.070007  181.449997  182.740005  182.492477
# 10942  2024-05-09  182.559998  184.660004  182.110001  184.570007  184.320007
# 10943  2024-05-10  184.899994  185.089996  182.130005  183.050003  183.050003
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10954 entries, 0 to 10953
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       10954 non-null  object
#  1   Open       10954 non-null  float64
#  2   High       10954 non-null  float64
#  3   Low        10954 non-null  float64
#  4   Close      10954 non-null  float64
#  5   Adj Close  10954 non-null  float64
#  6   Volume     10954 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 599.2+ KB

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10954.000000  10954.000000  10954.000000  10954.000000  10954.000000
# mean      21.530877     21.761904     21.308220     21.544072     20.747506
# std       44.458386     44.931856     44.013578     44.492483     44.038943
# min        0.049665      0.049665      0.049107      0.049107      0.037900
# 25%        0.296875      0.303571      0.290179      0.296875      0.241624
# 50%        0.522321      0.533482      0.513393      0.524554      0.427333
# 75%       19.767500     19.888572     19.457768     19.682679     17.048054
# max      198.020004    199.619995    197.000000    198.110001    197.589523
#
#              Volume
# count  1.095400e+04
# mean   3.190792e+08
# std    3.357446e+08
# min    0.000000e+00
# 25%    1.139936e+08
# 50%    2.067128e+08
# 75%    3.993444e+08
# max    7.421641e+09

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.size
# Out:
# 76678

# %%
df.shape
# Out:
# (10954, 7)

# %%
df.loc[9553]
# Out:
# Date         2018-10-30
# Open          52.787498
# High          53.794998
# Low           52.317501
# Close         53.325001
# Adj Close     50.869957
# Volume        146640000
# Name: 9553, dtype: object

# %%
df.iloc[3011:3025]
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 3011  1992-11-09  0.500000  0.500000  0.488839  0.493304   0.400828  112929600
# 3012  1992-11-10  0.491071  0.504464  0.488839  0.502232   0.408082  122225600
# 3013  1992-11-11  0.504464  0.520089  0.502232  0.506696   0.411709  140425600
# 3014  1992-11-12  0.508929  0.513393  0.503348  0.507813   0.412617  107598400
# 3015  1992-11-13  0.508929  0.511161  0.500000  0.502232   0.408082   84750400
# 3016  1992-11-16  0.502232  0.515625  0.500000  0.512277   0.416244   67547200
# 3017  1992-11-17  0.511161  0.513393  0.489955  0.493304   0.400828  168806400
# 3018  1992-11-18  0.500000  0.520089  0.495536  0.515625   0.418965  304808000
# 3019  1992-11-19  0.515625  0.531250  0.515625  0.520089   0.422592  240542400
# 3020  1992-11-20  0.522321  0.524554  0.508929  0.513393   0.417151  155489600
# 3021  1992-11-23  0.504464  0.508929  0.502232  0.506696   0.411709  152723200
# ...

# %%
df[df.index==10000]
# Out:
#              Date        Open        High         Low    Close   Adj Close  \
# 10000  2020-08-11  111.970001  112.482498  109.107498  109.375  107.009857
#
#           Volume
# 10000  187902400

# %%
df[df.index.isin(range(1005,1036))]
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 1005  1984-12-03  0.110491  0.111049  0.108817  0.108817   0.083984   98000000
# 1006  1984-12-04  0.111049  0.113281  0.111049  0.111049   0.085707  120377600
# 1007  1984-12-05  0.116629  0.116629  0.116629  0.116629   0.090013  262908800
# 1008  1984-12-06  0.122210  0.122768  0.122210  0.122210   0.094320  317273600
# 1009  1984-12-07  0.122210  0.126674  0.121094  0.121652   0.093890  494524800
# 1010  1984-12-10  0.121652  0.121652  0.119420  0.119420   0.092167  111484800
# 1011  1984-12-11  0.119420  0.121094  0.117746  0.117746   0.090875  123782400
# 1012  1984-12-12  0.117746  0.117746  0.113839  0.113839   0.087860  110073600
# 1013  1984-12-13  0.114955  0.117188  0.114955  0.114955   0.088721   66841600
# 1014  1984-12-14  0.114955  0.118862  0.114955  0.117746   0.090875   96140800
# 1015  1984-12-17  0.120536  0.121652  0.120536  0.120536   0.093029  125238400
# ...

# %%
df.count()
# Out:
# Date         10954
# Open         10954
# High         10954
# Low          10954
# Close        10954
# Adj Close    10954
# Volume       10954
# dtype: int64

# %%
df["Adj Close"].value_counts()
# Out:
# Adj Close
# 0.085276      20
# 0.052543      18
# 0.088721      17
# 0.093890      16
# 0.068910      16
#               ..
# 2.101855       1
# 2.086456       1
# 2.068037       1
# 2.143524       1
# 189.979996     1
# Name: count, Length: 7938, dtype: int64

# %%
df.drop(10009)
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099058
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093890
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086999
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089152
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091737
# ...           ...         ...         ...         ...         ...         ...
# 10949  2024-05-20  189.330002  191.919998  189.009995  191.039993  191.039993
# 10950  2024-05-21  191.089996  192.729996  190.919998  192.350006  192.350006
# 10951  2024-05-22  192.270004  192.820007  190.270004  190.899994  190.899994
# 10952  2024-05-23  190.979996  191.000000  186.630005  186.880005  186.880005
# 10953  2024-05-24  188.820007  190.580002  188.039993  189.979996  189.979996
#
#           Volume
# ...

# %%
df.nunique()
# Out:
# Date         10954
# Open          6262
# High          6205
# Low           6194
# Close         6370
# Adj Close     7938
# Volume       10390
# dtype: int64

# %% [markdown]
#  # Data Visualization using Matplotlib & Seaborn

# %%
SYK.pairplot(df)
# Out:
# C:\Users\SAI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
SYK.histplot(df["High"])
# Out:
# <Axes: xlabel='High', ylabel='Count'>

# %%
SYK.jointplot(X="Close",Y="Adj Close",data=df,kind="kde",fill=True)
PLE.show()
# Out:
# C:\Users\SAI\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'X', 'Y'
#   cset = contour_func(

# %%
PLE.figure(1,figsize=(15,6))
n=0;
for x in ["Open","Close","Volume"]:
    n += 1
    PLE.subplot(1,3,n)
    PLE.subplots_adjust(hspace=0.5,wspace=0.5)
    SYK.stripplot(df[x])
    PLE.title("Stripplot of {}".format(x))
PLE.show()

# %%
# Defining X
import pandas as PT
df = PT.read_csv("D:\Dataset\Apple Dataset.csv")
df
X = df.iloc[:,[1,2]].values

# %%
# Importing DBSCAN
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=3,min_samples=4)

# %%
# Fitting the model
model = dbscan.fit(X)
labels = model.labels_

# %%
labels
# Out:
# array([0, 0, 0, ..., 2, 2, 2], dtype=int64)

# %%
# Importing metrics
from sklearn import metrics
import numpy as NR
sample_cores=NR.zeros_like(labels,dtype=bool)

# %%
sample_cores
# Out:
# array([False, False, False, ..., False, False, False])

# %%
sample_cores[dbscan.core_sample_indices_]=True
sample_cores
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])
