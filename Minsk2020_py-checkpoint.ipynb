# %% [markdown]
#  # Importing Basic Libraries

# %%
import numpy as ns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
#  # Loading the Dataset

# %%
df1 = pd.read_csv("D:\\Dataset\\Minsk2020_ALS_dataset.csv")
df1
# Out:
#      ID Sex  Age      J1_a      J3_a      J5_a     J55_a       S1_a      S3_a  \
# 0     8   M   58  0.321817  0.141230  0.199128  0.923634   6.044559  3.196477
# 1    20   F   57  0.344026  0.177032  0.206458  0.827714   1.967728  0.856639
# 2    21   F   58  0.264740  0.148228  0.177078  0.532566   1.850893  0.942743
# 3    22   F   70  0.455793  0.174870  0.243660  0.962641   2.883768  1.284926
# 4    24   M   66  0.269335  0.143961  0.167465  0.547745   2.327924  1.164109
# ..  ...  ..  ...       ...       ...       ...       ...        ...       ...
# 59  123   M   43  0.255799  0.123679  0.182658  0.505591   6.222031  2.876602
# 60  125   M   63  0.513175  0.296489  0.334845  0.729804   9.686563  4.327943
# 61  127   F   67  0.383901  0.245923  0.251359  0.415136   4.148414  2.069757
# 62  129   F   68  1.336216  0.815757  0.733197  0.981928  11.224542  5.295879
# 63  131   F   60  0.916706  0.566121  0.512857  1.467165   6.372832  3.251168
#
# ...

# %%
# Checking Length for DataFrame
len(df1.columns)
# Out:
# 135

# %%
# Checking Null Values
df1.isna().sum().sum()
# Out:
# 0

# %%
# Checking data types
df1.dtypes
# Out:
# ID                   int64
# Sex                 object
# Age                  int64
# J1_a               float64
# J3_a               float64
#                     ...
# dCCi(12)           float64
# d_1                float64
# F2_i               float64
# F2_{conv}          float64
# Diagnosis (ALS)      int64
# Length: 135, dtype: object

# %%
# label encoder to numerize columns
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df1["Sex"] = lb.fit_transform(df1["Sex"])
df1
# Out:
#      ID  Sex  Age      J1_a      J3_a      J5_a     J55_a       S1_a  \
# 0     8    1   58  0.321817  0.141230  0.199128  0.923634   6.044559
# 1    20    0   57  0.344026  0.177032  0.206458  0.827714   1.967728
# 2    21    0   58  0.264740  0.148228  0.177078  0.532566   1.850893
# 3    22    0   70  0.455793  0.174870  0.243660  0.962641   2.883768
# 4    24    1   66  0.269335  0.143961  0.167465  0.547745   2.327924
# ..  ...  ...  ...       ...       ...       ...       ...        ...
# 59  123    1   43  0.255799  0.123679  0.182658  0.505591   6.222031
# 60  125    1   63  0.513175  0.296489  0.334845  0.729804   9.686563
# 61  127    0   67  0.383901  0.245923  0.251359  0.415136   4.148414
# 62  129    0   68  1.336216  0.815757  0.733197  0.981928  11.224542
# 63  131    0   60  0.916706  0.566121  0.512857  1.467165   6.372832
#
#         S3_a      S5_a  ...   dCCi(7)   dCCi(8)   dCCi(9)  dCCi(10)  dCCi(11)  \
# ...

# %% [markdown]
#  # Exploratory Data Analysis

# %%
df = df1.drop(columns='Sex')

# %%
len(df.columns)
# Out:
# 134

# %%
plt.figure(figsize=(8,120))
for i,j in enumerate(df.columns):
    plt.subplot(len(df.columns),1,i+1)
    plt.boxplot(df[j],vert=False)
    plt.title(j)
    plt.tight_layout()

# %% [markdown]
#  # Split X & y

# %%
# Defining X & y
X = df1.drop(columns = "Diagnosis (ALS)")
y = df1["Diagnosis (ALS)"]

# %%
# Importing Train_Test_Split
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold,cross_val_score

# %%
# Importing Different  Machine Learning Models and importing accuracy_score,classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2,stratify=y)

# %%
Model1 = DecisionTreeClassifier()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
Model1 = RandomForestClassifier()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.7692307692307693

# %%
Model1 = SVC()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
Model1 = AdaBoostClassifier()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.8461538461538461

# %%
Model1 = LogisticRegression()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.8461538461538461

# %%
Model1 = GaussianNB()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6923076923076923

# %% [markdown]
#  # Using KFold Technique

# %%
kfold = KFold(8)
Model = DecisionTreeClassifier()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.375 0.75  0.875 0.625 0.5   0.625 0.625 0.5  ]
# mean of the scores -  0.609375
# standard deviation of the scores -  0.14574029770451274

# %%
kfold = KFold(8)
Model = RandomForestClassifier()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.5   0.75  0.75  0.5   0.75  0.375 0.875 0.125]
# mean of the scores -  0.578125
# standard deviation of the scores -  0.23333100817293873

# %%
kfold = KFold(8)
model = SVC()
score = cross_val_score(estimator=model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.25  0.5   0.375 0.25  0.5   0.625 0.625 0.5  ]
# mean of the scores -  0.453125
# standard deviation of the scores -  0.13887803777055607

# %%
kfold = KFold(8)
model = AdaBoostClassifier()
score = cross_val_score(estimator=model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.375 0.75  0.75  0.25  0.75  0.5   1.    0.25 ]
# mean of the scores -  0.578125
# standard deviation of the scores -  0.2572199630180364

# %%
kfold = KFold(8)
model = GaussianNB()
score = cross_val_score(estimator=model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.375 0.625 0.625 0.5   0.875 0.75  1.    0.125]
# mean of the scores -  0.609375
# standard deviation of the scores -  0.2609889545076573

# %%
kfold = KFold(8)
model = LogisticRegression()
score = cross_val_score(estimator=model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.75  0.875 0.5   0.125 0.375 0.625 0.75  0.375]
# mean of the scores -  0.546875
# standard deviation of the scores -  0.23333100817293873

# %% [markdown]
#  # Using StratifiedKFold Technique

# %%
skfold = StratifiedKFold(10)
model = DecisionTreeClassifier()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.85714286 0.42857143 0.42857143 0.57142857 0.83333333 0.83333333
#  0.66666667 0.83333333 0.66666667 0.5       ]
# mean of the scores -  0.661904761904762
# standard deviation of the scores -  0.1641994252339683

# %%
skfold = StratifiedKFold(11)
model = RandomForestClassifier()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.83333333 0.66666667 1.         0.5        0.66666667 0.83333333
#  0.83333333 1.         0.5        0.4        0.4       ]
# mean of the scores -  0.6939393939393941
# standard deviation of the scores -  0.21216449774805207

# %%
skfold = StratifiedKFold(7)
model = SVC()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.9        0.77777778 0.55555556 1.         0.77777778 0.44444444
#  0.44444444]
# mean of the scores -  0.7000000000000001
# standard deviation of the scores -  0.20479266411023764

# %%
skfold = StratifiedKFold(5)
model = LogisticRegression()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.61538462 0.84615385 0.84615385 0.69230769 0.41666667]
# mean of the scores -  0.6833333333333333
# standard deviation of the scores -  0.1605177356501491

# %%
skfold = StratifiedKFold(9)
model = GaussianNB()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.75       0.57142857 0.85714286 0.57142857 0.71428571 0.85714286
#  0.71428571 0.57142857 0.42857143]
# mean of the scores -  0.6706349206349206
# standard deviation of the scores -  0.13654484550861312

# %%
skfold = StratifiedKFold(8)
model = AdaBoostClassifier()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [1.    0.625 0.75  0.75  1.    0.875 1.    0.25 ]
# mean of the scores -  0.78125
# standard deviation of the scores -  0.240035804620894

# %% [markdown]
#  # Select KBest Technique

# %%
# Defining X & y
X = df1.drop(columns = "Diagnosis (ALS)")
y = df1["Diagnosis (ALS)"]

# %%
# Train_Test_Split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,random_state=42,test_size=0.2,stratify=y)

# %%
# Importing SelectKBest,chi2,f_classif
from sklearn.feature_selection import SelectKBest,chi2,f_classif

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler1 = MinMaxScaler()
X_scaled = Scaler1.fit_transform(X)

# %%
kbest10 = SelectKBest(chi2,k=10)
best_10 = kbest10.fit(X_scaled,y)
best_10.get_support()
X.columns[best_10.get_support()]
# Out:
# Index(['J55_a', 'PFR_a', 'PPE_a', 'PVI_a', 'GNEa_{\mu}', 'Ha(4)_{sd}',
#        'Ha(7)_{rel}', 'PVI_i', 'Hi(1)_{rel}', 'CCi(6)'],
#       dtype='object')

# %%
X = df1[['J55_a', 'PFR_a', 'PPE_a', 'PVI_a', 'GNEa_{\mu}', 'Ha(4)_{sd}',
       'Ha(7)_{rel}', 'PVI_i', 'Hi(1)_{rel}', 'CCi(6)']]

# %%
Model = DecisionTreeClassifier()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
Model = RandomForestClassifier()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
Model = SVC()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
Model = AdaBoostClassifier()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
Model = LogisticRegression()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
Model = GaussianNB()
Model1.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %% [markdown]
#  # Cross Validation after SelectKBest

# %% [markdown]
#  # Using KFold After SelectKBest

# %%
kfold = KFold(8)
Model = DecisionTreeClassifier()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.375 0.875 0.75  0.625 0.375 0.75  1.    0.5  ]
# mean of the scores -  0.65625
# standard deviation of the scores -  0.21423920626253262

# %%
kfold = KFold(3)
Model = RandomForestClassifier()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.31818182 0.57142857 0.42857143]
# mean of the scores -  0.4393939393939394
# standard deviation of the scores -  0.10367038973877096

# %%
kfold = KFold(5)
Model = AdaBoostClassifier()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.53846154 0.84615385 0.61538462 0.61538462 0.41666667]
# mean of the scores -  0.6064102564102564
# standard deviation of the scores -  0.1401839685419143

# %%
kfold = KFold(4)
Model = GaussianNB()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.5625 0.5625 0.8125 0.625 ]
# mean of the scores -  0.640625
# standard deviation of the scores -  0.10245997694221876

# %%
kfold = KFold(6)
Model = SVC()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.45454545 0.72727273 0.36363636 0.54545455 1.         0.6       ]
# mean of the scores -  0.6151515151515151
# standard deviation of the scores -  0.20608288649599157

# %%
kfold = KFold(4)
Model = LogisticRegression()
score = cross_val_score(estimator=Model,X=X,y=y,cv=kfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.5    0.625  0.5    0.3125]
# mean of the scores -  0.484375
# standard deviation of the scores -  0.11158481919598204

# %% [markdown]
# # Using StratifiedKFold after SelectKBest

# %%
skfold = StratifiedKFold(5)
model = GaussianNB()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.69230769 0.76923077 0.84615385 0.84615385 0.5       ]
# mean of the scores -  0.7307692307692308
# standard deviation of the scores -  0.12871692715908856

# %%
skfold = StratifiedKFold(4)
model = RandomForestClassifier()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.625  0.75   0.9375 0.6875]
# mean of the scores -  0.75
# standard deviation of the scores -  0.11692679333668567

# %%
skfold = StratifiedKFold(3)
model = DecisionTreeClassifier()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.68181818 0.85714286 0.57142857]
# mean of the scores -  0.7034632034632035
# standard deviation of the scores -  0.11764223585888477

# %%
skfold = StratifiedKFold(4)
model = AdaBoostClassifier()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.5625 0.75   0.875  0.9375]
# mean of the scores -  0.78125
# standard deviation of the scores -  0.14320549046737

# %%
skfold = StratifiedKFold(2)
model = LogisticRegression()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.78125 0.65625]
# mean of the scores -  0.71875
# standard deviation of the scores -  0.0625

# %%
skfold = StratifiedKFold(5)
model = SVC()
score = cross_val_score(estimator=model,X=X,y=y,cv=skfold)
print('scores - ', score)
print('mean of the scores - ',score.mean())
print('standard deviation of the scores - ',score.std())
# Out:
# scores -  [0.53846154 0.76923077 0.84615385 0.92307692 0.5       ]
# mean of the scores -  0.7153846153846153
# standard deviation of the scores -  0.16782634022516488

# %% [markdown]
#  # HyperParameter Tuning

# %%
Model = AdaBoostClassifier(n_estimators=50,base_estimator=DecisionTreeClassifier(),learning_rate=1)
Model.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# GridSearch using AdaBoostClassifier
param_grid = {
    'n_estimators': [50],
    'learning_rate': [ 1.0],
    'base_estimator':[DecisionTreeClassifier()]
}
# Perform Grid Search with cross-validation
grid_search = GridSearchCV(Model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters found by Grid Search
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_model = grid_search.best_estimator_
# Out:
# Best Hyperparameters: {'base_estimator': DecisionTreeClassifier(), 'learning_rate': 1.0, 'n_estimators': 50}

# %%
Model = RandomForestClassifier(n_estimators=100,max_depth=40,min_samples_split=5,min_samples_leaf=4,max_features=1,
                               bootstrap = True)
Model.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
# GridSearch using RandomForest Classifier
# Define the hyperparameter grid for Grid Search
param_grid = {
    'n_estimators': [100],
    'max_depth': [40],
    'min_samples_split': [5],
    'min_samples_leaf': [4],
    'max_features': ['sqrt'],
    'bootstrap': [True]
}

# Perform Grid Search with cross-validation
grid_search = GridSearchCV(Model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters found by Grid Search
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_model = grid_search.best_estimator_
# Out:
# Best Hyperparameters: {'bootstrap': True, 'max_depth': 40, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}

# %%
Model = DecisionTreeClassifier(criterion="gini",max_depth=10,min_samples_split=5,min_samples_leaf=4,max_features=1,
                               splitter='best')
Model.fit(X_train,y_train)
pred = Model1.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.6153846153846154

# %%
# Define the hyperparameter grid for Grid Search
param_grid = {
    'criterion': ['gini'],
    'max_depth': [10],
    'min_samples_split': [5],
    'min_samples_leaf': [4],
    'max_features': ['auto', 'sqrt'],
    'splitter': ['best', 'random']
}

# Perform Grid Search with cross-validation
grid_search = GridSearchCV(Model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters found by Grid Search
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_model = grid_search.best_estimator_
# Out:
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'splitter': 'random'}

# %% [markdown]
#  # Classification Report

# %%
Model = DecisionTreeClassifier()
Model.fit(X_train,y_train)
pred = Model1.predict(X_test)
report = classification_report(y_test,pred)
print("classification Report:\n", report)
# Out:
# classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.60      0.50      0.55         6
#
#     accuracy                           0.62        13
#    macro avg       0.61      0.61      0.61        13
# weighted avg       0.61      0.62      0.61        13
