.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df1.nunique()
# Out:
# Date         698
# Open         546
# High         558
# Low          557
# Close        570
# Adj Close    570
# Volume       698
# dtype: int64

# %%
df1.count()
# Out:
# Date         698
# Open         698
# High         698
# Low          698
# Close        698
# Adj Close    698
# Volume       698
# dtype: int64

# %%
df1["Close"].value_counts()
# Out:
# Close
# 53.950001     5
# 64.449997     4
# 63.000000     4
# 134.949997    4
# 139.550003    3
#              ..
# 69.900002     1
# 72.150002     1
# 71.949997     1
# 74.699997     1
# 185.500000    1
# Name: count, Length: 570, dtype: int64

# %% [markdown]
#  # Data Visualization using Matplotlib & Seaborn

# %%
spm.pairplot(df1)
# Out:
# C:\Users\SAI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = pld.figure()
ax = fig.add_subplot(111, projection='3d')
X1 = nd.random.normal(0, 1, 100)
Y1 = nd.random.normal(0, 1, 100)
Z1 = nd.random.normal(0, 1, 100)
ax.scatter(X1, Y1, Z1)

# %%
df1 = nd.random.rand(10, 10)
pld.imshow(df1, cmap='hot', interpolation='nearest')
pld.colorbar()
pld.show()

# %%
import matplotlib.pyplot as pld
import numpy as nd
X = nd.linspace(0,10,100)
Y1 = nd.sin(X)
Y2 = nd.cos(X)
fig,(ax1,ax2) = pld.subplots(2,sharex=True)
ax1.plot(X,Y1)
ax1.set_title("Shared X_axis")
ax2.plot(X,Y2)
pld.show()

# %% [markdown]
#  # Split X & Y

# %%
X = nd.delete(df1,0,axis=0)
Y = nd.delete(df1,1,axis=1)

# %%
import numpy as nd

extra_samples = 90 - 39  # Calculate the difference in sample counts
padding = nd.zeros((extra_samples, X.shape[1]))  # Assuming X is a 2D array
X = nd.vstack([X, padding])

# %%
y_1d = nd.ravel(Y)

# %% [markdown]
#  # Importing MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
X_scaled = scalar.fit_transform(X)
X_scaled
# Out:
# array([[1.        , 0.66866013, 0.26960316, 1.        , 0.28331841,
#         0.34048337, 0.60500607, 0.0517575 , 0.74278313, 0.6860332 ],
#        [0.72264056, 0.17196114, 0.98111005, 0.4729889 , 0.10164379,
#         1.        , 0.47383673, 0.28008046, 0.94193648, 0.19742897],
#        [0.81695085, 0.02943802, 0.92331591, 0.35542013, 0.66020104,
#         0.6805091 , 1.        , 0.72979367, 0.62154029, 1.        ],
#        [0.73611334, 0.76458547, 0.14577278, 0.34088437, 0.70879543,
#         0.42520359, 0.25848457, 0.34075236, 0.54986425, 0.16011631],
#        [0.29944511, 0.53802656, 1.        , 0.60374586, 1.        ,
#         0.61341274, 0.15944619, 0.08590133, 0.12200593, 0.1834948 ],
#        [0.45085096, 0.63926684, 0.69359386, 0.70122322, 0.79777076,
#         0.19922524, 0.05670139, 0.8465618 , 0.46486179, 0.40988818],
#        [0.18922695, 1.        , 0.66829966, 0.53758877, 0.20140822,
#         0.67023568, 0.20351394, 1.        , 0.96615065, 0.95784355],
# ...

# %% [markdown]
#  # Importing LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_1d)

# %% [markdown]
#  # Train_Test_Split

# %%
from sklearn.model_selection import train_test_split
X_train,Y_train,X_test,Y_test = train_test_split(X,y_1d,test_size=0.2,random_state=42)

# %% [markdown]
#  # Importing KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
model1 = KNeighborsRegressor()
model1.fit(X,y_1d)
# Out:
# KNeighborsRegressor()

# %% [markdown]
#  # Predictions from our Model

# %%
spm.jointplot(y_1d)
