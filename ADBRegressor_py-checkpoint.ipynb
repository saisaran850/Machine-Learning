# %% [markdown]
#  # Importing Required Libraries

# %%
import numpy as ns
import pandas as py
import matplotlib.pyplot as pla
import seaborn as smm

# %% [markdown]
#  # Loading the Dataset

# %%
df = py.read_csv("D:\\Dataset\\Students Performance.csv")
df
# Out:
#      Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0            65             86             67               78            2021
# 1            64             85             71               80            2019
# 2            76             77             77               84            2021
# 3            80             76             75               75            2021
# 4            63             91             62               90            2019
# ..          ...            ...            ...              ...             ...
# 394          85             95             74               60            2020
# 395          67             87             96               93            2021
# 396          92             81             93               64            2021
# 397         100             64             97               88            2021
# 398          63             78             85               93            2020
#
# [399 rows x 5 columns]

# %% [markdown]
#  # Data Cleaning using Pandas

# %%
df.isna().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join_Date     0
# dtype: int64

# %%
df.head(15)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0           65             86             67               78            2021
# 1           64             85             71               80            2019
# 2           76             77             77               84            2021
# 3           80             76             75               75            2021
# 4           63             91             62               90            2019
# 5           73             95             62               79            2020
# 6           72             82             76               79            2020
# 7           77             82             62               87            2021
# 8           74             90             60              100            2019
# 9           68             85             72               89            2019
# 10          64             78             80               84            2019
# ...

# %%
df.tail(23)
# Out:
#      Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 376          65             92             92               78            2018
# 377          64             75            100               89            2018
# 378          92             67             80               87            2020
# 379          62             85             90               83            2020
# 380          73             96             84               64            2018
# 381          92             99             61               84            2020
# 382          99             82             61               74            2018
# 383          86             90             94               74            2020
# 384          91             93             87               85            2020
# 385          62             95             73               62            2021
# 386          91             72             79               65            2019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       399 non-null    int64
#  1   Reading_Score    399 non-null    int64
#  2   Writing_Score    399 non-null    int64
#  3   Placement_Score  399 non-null    int64
#  4   Club_Join_Date   399 non-null    int64
# dtypes: int64(5)
# memory usage: 15.7 KB

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count  399.000000     399.000000     399.000000       399.000000
# mean    79.182957      79.681704      79.167920        80.345865
# std     11.871765      11.319323      12.039064        11.452356
# min     60.000000      60.000000      60.000000        60.000000
# 25%     69.000000      70.000000      68.000000        71.000000
# 50%     79.000000      80.000000      78.000000        80.000000
# 75%     90.000000      89.000000      90.000000        89.000000
# max    100.000000     100.000000     100.000000       100.000000
#
#        Club_Join_Date
# count      399.000000
# mean      2019.481203
# std          1.115907
# min       2018.000000
# 25%       2018.000000
# 50%       2019.000000
# 75%       2020.000000
# max       2021.000000

# %%
df.nunique()
# Out:
# Math_Score         41
# Reading_Score      41
# Writing_Score      41
# Placement_Score    41
# Club_Join_Date      4
# dtype: int64

# %%
df.loc[98]
# Out:
# Math_Score           83
# Reading_Score        73
# Writing_Score        73
# Placement_Score      78
# Club_Join_Date     2018
# Name: 98, dtype: int64

# %%
df.iloc[60:91]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 60          83             65             82               83            2020
# 61          79             98             90               89            2019
# 62          92             63             72               69            2019
# 63          88             92             96              100            2019
# 64         100             62             97               80            2018
# 65          83             68             66               75            2019
# 66          72             94             83               60            2018
# 67          84             84             65              100            2021
# 68          61             64             66               70            2019
# 69          78            100             93               63            2020
# 70          64             70             92               63            2020
# ...

# %%
df.dtypes
# Out:
# Math_Score         int64
# Reading_Score      int64
# Writing_Score      int64
# Placement_Score    int64
# Club_Join_Date     int64
# dtype: object

# %%
df.size
# Out:
# 1995

# %%
df.shape
# Out:
# (399, 5)

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join_Date'],
#       dtype='object')

# %%
df[df.index==100]
# Out:
#      Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 100          98             96             89               76            2019

# %%
df[df.index.isin(range(20,46))]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 20          69             82             60               93            2021
# 21          68             90             66               83            2019
# 22          66             88             62               84            2018
# 23          75             75             80               89            2021
# 24          80             83             64               80            2020
# 25          71             95             60               95            2020
# 26          63             83             70               81            2019
# 27          62             77             67               78            2021
# 28          64             83             60               84            2021
# 29          72             82             61               95            2019
# 30          73             66             83               83            2019
# ...

# %%
df.count()
# Out:
# Math_Score         399
# Reading_Score      399
# Writing_Score      399
# Placement_Score    399
# Club_Join_Date     399
# dtype: int64

# %%
df["Placement_Score"].value_counts()
# Out:
# Placement_Score
# 84     18
# 93     17
# 77     17
# 80     16
# 83     15
# 69     15
# 89     14
# 88     13
# 85     13
# 78     13
# 60     13
# 100    13
# 95     12
# 94     12
# 75     11
# 76     11
# 97     11
# 63     10
# 62     10
# 65     10
# 87      9
# 74      9
# 64      9
# 71      9
# 98      8
# 82      8
# 86      7
# 67      7
# 68      7
# 79      7
# 73      6
# 66      6
# 81      6
# 91      6
# 70      5
# 61      5
# 90      5
# 72      4
# 92      4
# 99      4
# 96      4
# Name: count, dtype: int64

# %% [markdown]
#  # Data Visualization using Matplotlib & Seaborn

# %%
smm.pairplot(df)
# Out:
# C:\Users\SAI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
smm.histplot(df["Club_Join_Date"])
# Out:
# <Axes: xlabel='Club_Join_Date', ylabel='Count'>

# %%
smm.scatterplot(df["Math_Score"])
# Out:
# <Axes: ylabel='Math_Score'>

# %%
import matplotlib.pyplot as pla
import numpy as ns
X = ns.linspace(0,200,400)
Y1 = ns.sin(X)
Y2 = ns.cos(X)
fig,(ax1,ax2) = pla.subplots(2,sharex=True)
ax1.plot(X,Y1)
ax1.set_title("Shared X_axis")
ax2.plot(X,Y2)
pla.show()

# %%
df = ns.random.rand(25,25)
pla.imshow(df, cmap='hot', interpolation='nearest')
pla.colorbar()
pla.show()

# %% [markdown]
#  # Split X & Y

# %%
X = ns.delete(df,0,axis=0)
Y = ns.delete(df,1,axis=1)

# %%
X.shape
# Out:
# (24, 25)

# %%
Y.shape
# Out:
# (25, 24)

# %%
X = ns.random.rand(600, 10)  # 600 samples, 10 features
y = ns.random.randint(0, 2, size=600)

# %%
y_1d = ns.ravel(Y)

# %% [markdown]
#  # Importing MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler = MinMaxScaler()
X1_Scaled = Scaler.fit_transform(X)
X1_Scaled
# Out:
# array([[0.5800979 , 0.68113858, 0.70961247, ..., 0.72239952, 0.41031458,
#         0.7836858 ],
#        [0.594965  , 0.62299516, 0.57338595, ..., 0.27892825, 0.83496948,
#         0.79545156],
#        [0.4428541 , 0.93041841, 0.75950734, ..., 0.96254662, 0.07907295,
#         0.28387634],
#        ...,
#        [0.88475943, 0.72081863, 0.30705297, ..., 0.0546807 , 0.97432908,
#         0.64638757],
#        [0.00228894, 0.55638546, 0.22993974, ..., 0.24154471, 0.84823754,
#         0.15862734],
#        [0.19219826, 0.11009602, 0.91081813, ..., 0.85539574, 0.64036698,
#         0.04957593]])

# %% [markdown]
#  # Importing LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder1 = LabelEncoder()
Y1_encoded = Label_Encoder1.fit_transform(y_1d)

# %% [markdown]
#  # Train_Test_Split

# %%
from sklearn.model_selection import train_test_split
X1_train,Y1_train,X1_test,Y1_test = train_test_split(X,y_1d,test_size=0.2,random_state=42)

# %% [markdown]
#  # Importing AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
Adc1 = AdaBoostRegressor(n_estimators=50,learning_rate=1,random_state=42)
Model_1 = Adc1.fit(X,y_1d)

# %% [markdown]
#  # Predictions From Our Model

# %%
smm.jointplot(y_1d)

# %%
smm.countplot(y_1d)
# Out:
# <Axes: ylabel='count'>
