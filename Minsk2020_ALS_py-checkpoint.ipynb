# %% [markdown]
#  # Importing Basic Libraries

# %%
import numpy as ns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
#  # Loading the Dataset

# %%
df1 = pd.read_csv("D:\\Dataset\\Minsk2020_ALS_dataset.csv")
df1
# Out:
#      ID Sex  Age      J1_a      J3_a      J5_a     J55_a       S1_a      S3_a  \
# 0     8   M   58  0.321817  0.141230  0.199128  0.923634   6.044559  3.196477
# 1    20   F   57  0.344026  0.177032  0.206458  0.827714   1.967728  0.856639
# 2    21   F   58  0.264740  0.148228  0.177078  0.532566   1.850893  0.942743
# 3    22   F   70  0.455793  0.174870  0.243660  0.962641   2.883768  1.284926
# 4    24   M   66  0.269335  0.143961  0.167465  0.547745   2.327924  1.164109
# ..  ...  ..  ...       ...       ...       ...       ...        ...       ...
# 59  123   M   43  0.255799  0.123679  0.182658  0.505591   6.222031  2.876602
# 60  125   M   63  0.513175  0.296489  0.334845  0.729804   9.686563  4.327943
# 61  127   F   67  0.383901  0.245923  0.251359  0.415136   4.148414  2.069757
# 62  129   F   68  1.336216  0.815757  0.733197  0.981928  11.224542  5.295879
# 63  131   F   60  0.916706  0.566121  0.512857  1.467165   6.372832  3.251168
#
# ...

# %%
# Checking Length for DataFrame
len(df1.columns)
# Out:
# 135

# %%
# Checking Null Values
df1.isna().sum().sum()
# Out:
# 0

# %%
# Checking data types
df1.dtypes
# Out:
# ID                   int64
# Sex                 object
# Age                  int64
# J1_a               float64
# J3_a               float64
#                     ...
# dCCi(12)           float64
# d_1                float64
# F2_i               float64
# F2_{conv}          float64
# Diagnosis (ALS)      int64
# Length: 135, dtype: object

# %% [markdown]
#  # Exploratory Data Analysis

# %%
# Convert non-numeric columns to numeric types if necessary  
for column in df1.columns:  
   if not pd.api.types.is_numeric_dtype(df1[column]):  
      df1[column] = pd.to_numeric(df1[column], errors='coerce')  
  
# Initialize a figure and axis object  
fig, axes = plt.subplots(nrows=len(df1.columns), ncols=1, figsize=(6, 40))  
  
# Iterate over the columns of your DataFrame and the axes  
for i, (column, ax) in enumerate(zip(df1.columns, axes)):  
   ax.boxplot(df1[column].dropna())  # Drop any NaN values  
   ax.set_title(column)  
  
# Display the plot  
plt.tight_layout()  
plt.show()

# %% [markdown]
#  # Split X & y

# %%
# Defining X & y
X = df1.drop(columns = "Diagnosis (ALS)")
y = df1["Diagnosis (ALS)"]

# %%
# Importing Train_Test_Split
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold,cross_val_score

# %%
# Importing Different  Machine Learning Models and importing accuracy_score,classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2,stratify=y)

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and DecisionTreeClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), DecisionTreeClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.6923076923076923

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and RandomForestclassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), RandomForestClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.8461538461538461

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and SVC classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), SVC())# Importing Simple Imputer and Pipeline
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.6153846153846154

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and AdaBoostclassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), AdaBoostClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.8461538461538461

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and KNeighborsclassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), KNeighborsClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.6923076923076923

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and GaussianNB()
pipeline = make_pipeline(SimpleImputer(strategy='mean'), GaussianNB())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.6923076923076923

# %% [markdown]
# # Using KFold Technique

# %%
# Create a pipeline with an imputer and Decision Tree classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), DecisionTreeClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.5833333333333334

# %%
# Create a pipeline with an imputer and Gaussian Naive Bayes classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), GaussianNB())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.3076923076923077
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.4166666666666667

# %%
# Create a pipeline with an imputer and KNeighbors classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), KNeighborsClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.38461538461538464
# Accuracy for this fold: 0.5

# %%
# Create a pipeline with an imputer and  AdaBoostClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), AdaBoostClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.9230769230769231
# Accuracy for this fold: 0.23076923076923078
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.5833333333333334

# %%
# Create a pipeline with an imputer and SVC
pipeline = make_pipeline(SimpleImputer(strategy='mean'), SVC())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.0
# Accuracy for this fold: 0.07692307692307693
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.4166666666666667

# %%
# Create a pipeline with an imputer and RandomForestClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), RandomForestClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.16666666666666666

# %% [markdown]
#  # Using Stratified KFold Technique

# %%
# Create a pipeline with an imputer and RandomForestClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), RandomForestClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.9230769230769231
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.5

# %%
# Create a pipeline with an imputer and SVC
pipeline = make_pipeline(SimpleImputer(strategy='mean'), SVC())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.5

# %%
# Create a pipeline with an imputer and AdaBoostClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), AdaBoostClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.9230769230769231
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.5833333333333334

# %%
# Create a pipeline with an imputer and GaussianNB()
pipeline = make_pipeline(SimpleImputer(strategy='mean'), GaussianNB())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.5833333333333334

# %%
# Create a pipeline with an imputer and DecisionTreeClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), DecisionTreeClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.38461538461538464
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.9230769230769231
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.75

# %%
# Create a pipeline with an imputer and KNeighborsClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), KNeighborsClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.5

# %% [markdown]
#  # Importing SelectKBest

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
selectkbest_f = SelectKBest(f_classif,k=10)

# %%
from sklearn.pipeline import Pipeline  
from sklearn.impute import SimpleImputer  
from sklearn.feature_selection import SelectKBest  
  
# Create a pipeline with an imputer and SelectKBest  
pipeline = Pipeline([  
   ('imputer', SimpleImputer(strategy='mean')),  # replace NaN with mean value  
   ('selector', SelectKBest(k=10))  # select top 10 features  
])  
  
# Fit the pipeline to your data  
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('selector', SelectKBest())])

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and RandomForestclassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), RandomForestClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.5833333333333334

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and GaussianNB()
pipeline = make_pipeline(SimpleImputer(strategy='mean'), GaussianNB())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.5833333333333334

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and KNeighborsclassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), KNeighborsClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.5

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and DecisionTreeClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), DecisionTreeClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.75

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and SVC classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), SVC())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.5

# %%
# Importing Simple Imputer and Pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
# Create a pipeline with an imputer and AdaBoostclassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), AdaBoostClassifier())
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Evaluate the model on the test data
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
pred = pipeline.predict(X_test)
# Out:
# Accuracy: 0.5833333333333334

# %% [markdown]
#  # Implementation of Cross Validation technique after Select KBest

# %% [markdown]
#  # 1.Using KFold

# %%
# Create a pipeline with an imputer and Decision Tree classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), DecisionTreeClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.25

# %%
# Create a pipeline with an imputer and Gaussian Naive Bayes classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), GaussianNB())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.3076923076923077
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.4166666666666667

# %%
# Create a pipeline with an imputer and KNeighbors classifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), KNeighborsClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.38461538461538464
# Accuracy for this fold: 0.5

# %%
# Create a pipeline with an imputer and  AdaBoostClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), AdaBoostClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.9230769230769231
# Accuracy for this fold: 0.23076923076923078
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.5833333333333334

# %%
# Create a pipeline with an imputer and SVC
pipeline = make_pipeline(SimpleImputer(strategy='mean'), SVC())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.0
# Accuracy for this fold: 0.07692307692307693
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.4166666666666667

# %%
# Create a pipeline with an imputer and RandomForestClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), RandomForestClassifier())

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.46153846153846156
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.25

# %% [markdown]
#  # 2.Using Stratified KFold

# %%
# Create a pipeline with an imputer and RandomForestClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), RandomForestClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.6666666666666666

# %%
# Create a pipeline with an imputer and SVC
pipeline = make_pipeline(SimpleImputer(strategy='mean'), SVC())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 0.5

# %%
# Create a pipeline with an imputer and AdaBoostClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), AdaBoostClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.9230769230769231
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.5833333333333334

# %%
# Create a pipeline with an imputer and GaussianNB()
pipeline = make_pipeline(SimpleImputer(strategy='mean'), GaussianNB())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.8461538461538461
# Accuracy for this fold: 0.5833333333333334

# %%
# Create a pipeline with an imputer and DecisionTreeClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), DecisionTreeClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.38461538461538464
# Accuracy for this fold: 0.6153846153846154
# Accuracy for this fold: 1.0
# Accuracy for this fold: 0.9230769230769231
# Accuracy for this fold: 0.75

# %%
# Create a pipeline with an imputer and KNeighborsClassifier
pipeline = make_pipeline(SimpleImputer(strategy='mean'), KNeighborsClassifier())

# Define the number of folds for cross-validation
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds)

# Perform K-Fold Cross-Validation
for train_index, test_index in skf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Fit the pipeline on the training data
    pipeline.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = pipeline.predict(X_test)

    # Calculate accuracy for this fold
    fold_accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for this fold: {fold_accuracy}")
# Out:
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.5384615384615384
# Accuracy for this fold: 0.7692307692307693
# Accuracy for this fold: 0.6923076923076923
# Accuracy for this fold: 0.5

# %% [markdown]
#  # Hyper Parameter Tuning

# %% [markdown]
# # 1.DecisionTreeClassifier using Hyper Parameters and Grid Search

# %%
# Importing GridSearchCV,RandomizedSearchCV
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
Model = DecisionTreeClassifier(criterion="gini",max_depth=1,min_samples_split=2,min_samples_leaf=1,max_features=1)
Model.fit(X_train,y_train)
pred = Model.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.5833333333333334

# %%
# Applying GridSearch to DecisionTreeClassifier
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}
# Initialize the DecisionTreeClassifier
Model1 = DecisionTreeClassifier()

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=Model1, param_grid=param_grid, cv=5, n_jobs=-1, scoring='accuracy')
grid_search.fit(X, y)
print("Best parameters found: ", grid_search.best_params_)
print("Best accuracy score: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best accuracy score:  0.826923076923077

# %% [markdown]
#  # 2.Random Forest Classifier Using Hyper Parameters and Randomized Search

# %%
Model = RandomForestClassifier(
